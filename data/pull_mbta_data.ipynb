# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone
import time
import os 
from zoneinfo import ZoneInfo

# %%
ROUTE_ID = "Orange"
OUTPUT_SCHEDULE = "orange_line_schedule_live.csv"
OUTPUT_REALTIME = "orange_line_realtime_live.csv"

COLLECTION_INTERVAL_MINUTES = 1
TOTAL_DURATION_HOURS = 9      
ITERATIONS = int((TOTAL_DURATION_HOURS * 60) / COLLECTION_INTERVAL_MINUTES)
eastern = ZoneInfo("America/New_York")

# %%
def collect_mbta_data():
    eastern = ZoneInfo("America/New_York")
    now = datetime.now(eastern)
    end_time = now + timedelta(hours=9)
    
    start_str = now.strftime("%H:%M")
    end_str = end_time.strftime("%H:%M")

    ## scheduled data
    schedule_url = "https://api-v3.mbta.com/schedules"
    schedule_params = {
        "filter[route]": ROUTE_ID,
        "filter[min_time]": start_str,
        "filter[max_time]": end_str,
        "page[limit]": 5000,
        "include": "stop,trip"
    }
    
    sched_resp = requests.get(schedule_url, params=schedule_params)
    schedule_rows = []
    for item in sched_resp.json().get("data", []):
        rel = item["relationships"]
        attrs = item["attributes"]
        schedule_rows.append({
            "trip_id": rel["trip"]["data"]["id"] if rel.get("trip") else None,
            "stop_id": rel["stop"]["data"]["id"] if rel.get("stop") else None,
            "stop_sequence": attrs.get("stop_sequence"),
            "arrival_time": attrs.get("arrival_time"),
            "departure_time": attrs.get("departure_time"),
            "direction_id": attrs.get("direction_id"),
            "timestamp_collected": now.isoformat(),
            "schedule_type": "planned"
        })
    schedule_df = pd.DataFrame(schedule_rows)

    # real-time data pull
    pred_url = "https://api-v3.mbta.com/predictions"
    pred_params = {
        "filter[route]": ROUTE_ID,
        "page[limit]": 5000,
        "include": "stop,trip"
    }
    pred_resp = requests.get(pred_url, params=pred_params)
    pred_rows = []
    for item in pred_resp.json().get("data", []):
        rel = item["relationships"]
        attrs = item["attributes"]
        pred_rows.append({
            "trip_id": rel["trip"]["data"]["id"] if rel.get("trip") and rel["trip"]["data"] else None,
            "stop_id": rel["stop"]["data"]["id"] if rel.get("stop") and rel["stop"]["data"] else None,
            "arrival_time": attrs.get("arrival_time"),
            "departure_time": attrs.get("departure_time"),
            "status": attrs.get("status"),
            "direction_id": attrs.get("direction_id"),
            "timestamp_collected": now.isoformat(),
            "schedule_type": "realtime"
        })
    pred_df = pd.DataFrame(pred_rows)


    if not schedule_df.empty:
        if os.path.exists(OUTPUT_SCHEDULE):
            schedule_df.to_csv(OUTPUT_SCHEDULE, mode="a", header=False, index=False)
        else:
            schedule_df.to_csv(OUTPUT_SCHEDULE, index=False)
    if not pred_df.empty:
        if os.path.exists(OUTPUT_REALTIME):
            pred_df.to_csv(OUTPUT_REALTIME, mode="a", header=False, index=False)
        else:
            pred_df.to_csv(OUTPUT_REALTIME, index=False)

    print(f"[{now:%H:%M:%S}] Collected {len(schedule_df)} schedule rows and {len(pred_df)} realtime rows.")

# %%
## the loop
print(f"Starting MBTA Orange Line data collection for {TOTAL_DURATION_HOURS} hours")
for i in range(ITERATIONS):
    collect_mbta_data()
    if i < ITERATIONS - 1:
        print(f"Waiting {COLLECTION_INTERVAL_MINUTES} minutes before next collection...\n")
        time.sleep(COLLECTION_INTERVAL_MINUTES * 60)

print("Data Collection Complete.")
# Out:
# Starting MBTA Orange Line data collection for 9 hours
# [14:55:04] Collected 4090 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [14:56:05] Collected 4086 schedule rows and 532 realtime rows.
# Waiting 1 minutes before next collection...
#
# [14:57:06] Collected 4085 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [14:58:07] Collected 4080 schedule rows and 538 realtime rows.
# Waiting 1 minutes before next collection...
#
# [14:59:09] Collected 4078 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:00:10] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:01:11] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:02:11] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:03:12] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:04:12] Collected 0 schedule rows and 560 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:05:13] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:06:13] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:07:14] Collected 0 schedule rows and 538 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:08:14] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:09:15] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:10:15] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:11:16] Collected 0 schedule rows and 564 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:12:16] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:13:17] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:14:17] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:15:18] Collected 0 schedule rows and 553 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:16:18] Collected 0 schedule rows and 545 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:17:19] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:18:19] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:19:20] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:20:20] Collected 0 schedule rows and 570 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:21:21] Collected 0 schedule rows and 565 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:22:21] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:23:23] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:24:24] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:25:24] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:26:25] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:27:25] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:28:26] Collected 0 schedule rows and 564 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:29:26] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:30:27] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:31:27] Collected 0 schedule rows and 541 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:32:28] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:33:28] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:34:29] Collected 0 schedule rows and 553 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:35:29] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:36:30] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:37:30] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:38:31] Collected 0 schedule rows and 540 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:39:31] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:40:32] Collected 0 schedule rows and 565 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:41:33] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:42:33] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:43:34] Collected 0 schedule rows and 559 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:44:34] Collected 0 schedule rows and 553 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:45:35] Collected 0 schedule rows and 546 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:46:35] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:47:36] Collected 0 schedule rows and 567 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:48:36] Collected 0 schedule rows and 559 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:49:37] Collected 0 schedule rows and 572 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:50:37] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:51:37] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:52:38] Collected 0 schedule rows and 549 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:53:39] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:54:39] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:55:40] Collected 0 schedule rows and 564 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:56:40] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:57:41] Collected 0 schedule rows and 547 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:58:41] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [15:59:42] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:00:43] Collected 0 schedule rows and 545 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:01:43] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:02:44] Collected 0 schedule rows and 549 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:03:44] Collected 0 schedule rows and 559 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:04:45] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:05:46] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:06:46] Collected 0 schedule rows and 536 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:07:46] Collected 0 schedule rows and 525 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:08:47] Collected 0 schedule rows and 520 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:09:47] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:10:48] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:11:48] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:12:49] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:13:49] Collected 0 schedule rows and 540 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:14:50] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:15:50] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:16:51] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:17:51] Collected 0 schedule rows and 547 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:18:52] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:19:52] Collected 0 schedule rows and 569 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:20:52] Collected 0 schedule rows and 563 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:21:53] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:22:53] Collected 0 schedule rows and 549 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:23:54] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:24:54] Collected 0 schedule rows and 571 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:25:55] Collected 0 schedule rows and 564 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:26:55] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:27:56] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:28:56] Collected 0 schedule rows and 577 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:29:57] Collected 0 schedule rows and 571 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:30:57] Collected 0 schedule rows and 563 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:31:58] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:32:58] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:33:58] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:34:59] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:35:59] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:37:00] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:38:00] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:39:01] Collected 0 schedule rows and 559 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:40:01] Collected 0 schedule rows and 572 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:41:02] Collected 0 schedule rows and 565 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:42:02] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:43:03] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:44:03] Collected 0 schedule rows and 541 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:45:04] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:46:05] Collected 0 schedule rows and 545 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:47:05] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:48:06] Collected 0 schedule rows and 545 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:49:06] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:50:06] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:51:07] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:52:07] Collected 0 schedule rows and 532 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:53:08] Collected 0 schedule rows and 526 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:54:08] Collected 0 schedule rows and 532 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:55:09] Collected 0 schedule rows and 528 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:56:09] Collected 0 schedule rows and 520 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:57:10] Collected 0 schedule rows and 528 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:58:10] Collected 0 schedule rows and 524 realtime rows.
# Waiting 1 minutes before next collection...
#
# [16:59:10] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:00:11] Collected 0 schedule rows and 546 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:01:11] Collected 0 schedule rows and 537 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:02:12] Collected 0 schedule rows and 528 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:03:12] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:04:13] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:05:13] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:06:14] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:07:14] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:08:15] Collected 0 schedule rows and 560 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:09:15] Collected 0 schedule rows and 553 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:10:16] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:11:16] Collected 0 schedule rows and 560 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:12:17] Collected 0 schedule rows and 547 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:13:17] Collected 0 schedule rows and 559 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:14:17] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:15:18] Collected 0 schedule rows and 565 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:16:18] Collected 0 schedule rows and 557 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:17:19] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:18:19] Collected 0 schedule rows and 560 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:19:20] Collected 0 schedule rows and 575 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:20:20] Collected 0 schedule rows and 566 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:21:21] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:22:21] Collected 0 schedule rows and 549 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:23:21] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:24:22] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:25:22] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:26:23] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:27:23] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:28:24] Collected 0 schedule rows and 521 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:29:25] Collected 0 schedule rows and 515 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:30:25] Collected 0 schedule rows and 526 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:31:26] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:32:27] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:33:27] Collected 0 schedule rows and 537 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:34:28] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:35:29] Collected 0 schedule rows and 542 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:36:29] Collected 0 schedule rows and 532 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:37:30] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:38:31] Collected 0 schedule rows and 515 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:39:31] Collected 0 schedule rows and 529 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:40:32] Collected 0 schedule rows and 521 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:41:32] Collected 0 schedule rows and 529 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:42:33] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:43:33] Collected 0 schedule rows and 536 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:44:34] Collected 0 schedule rows and 529 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:45:34] Collected 0 schedule rows and 520 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:46:35] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:47:35] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:48:36] Collected 0 schedule rows and 540 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:49:36] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:50:37] Collected 0 schedule rows and 562 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:51:38] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:52:39] Collected 0 schedule rows and 546 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:53:39] Collected 0 schedule rows and 542 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:54:40] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:55:40] Collected 0 schedule rows and 521 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:56:41] Collected 0 schedule rows and 514 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:57:41] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:58:42] Collected 0 schedule rows and 537 realtime rows.
# Waiting 1 minutes before next collection...
#
# [17:59:43] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:00:43] Collected 0 schedule rows and 540 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:01:44] Collected 0 schedule rows and 549 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:02:44] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:03:45] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:04:46] Collected 0 schedule rows and 546 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:05:47] Collected 0 schedule rows and 537 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:06:47] Collected 0 schedule rows and 528 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:07:48] Collected 0 schedule rows and 542 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:08:49] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:09:49] Collected 0 schedule rows and 567 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:10:49] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:11:50] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:12:50] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:13:51] Collected 0 schedule rows and 552 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:14:51] Collected 0 schedule rows and 546 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:15:53] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:16:54] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:17:55] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:18:56] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:19:57] Collected 0 schedule rows and 528 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:20:57] Collected 0 schedule rows and 540 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:21:57] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:22:58] Collected 0 schedule rows and 526 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:23:59] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:24:59] Collected 0 schedule rows and 556 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:26:00] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:27:00] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:28:01] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:29:01] Collected 0 schedule rows and 568 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:30:02] Collected 0 schedule rows and 564 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:31:02] Collected 0 schedule rows and 558 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:32:03] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:33:03] Collected 0 schedule rows and 545 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:34:04] Collected 0 schedule rows and 537 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:35:04] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:36:05] Collected 0 schedule rows and 522 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:37:06] Collected 0 schedule rows and 534 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:38:07] Collected 0 schedule rows and 524 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:39:07] Collected 0 schedule rows and 518 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:40:08] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:41:09] Collected 0 schedule rows and 519 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:42:09] Collected 0 schedule rows and 513 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:43:10] Collected 0 schedule rows and 523 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:44:10] Collected 0 schedule rows and 513 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:45:10] Collected 0 schedule rows and 525 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:46:11] Collected 0 schedule rows and 514 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:47:11] Collected 0 schedule rows and 529 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:48:12] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:49:13] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:50:13] Collected 0 schedule rows and 542 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:51:14] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:52:14] Collected 0 schedule rows and 543 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:53:15] Collected 0 schedule rows and 538 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:54:15] Collected 0 schedule rows and 548 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:55:16] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:56:16] Collected 0 schedule rows and 550 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:57:17] Collected 0 schedule rows and 563 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:58:17] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [18:59:18] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:00:18] Collected 0 schedule rows and 554 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:01:18] Collected 0 schedule rows and 551 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:02:19] Collected 0 schedule rows and 541 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:03:19] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:04:20] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:05:21] Collected 0 schedule rows and 555 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:06:21] Collected 0 schedule rows and 547 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:07:22] Collected 0 schedule rows and 542 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:08:22] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:09:23] Collected 0 schedule rows and 541 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:10:23] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:11:24] Collected 0 schedule rows and 526 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:12:24] Collected 0 schedule rows and 518 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:13:25] Collected 0 schedule rows and 507 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:14:25] Collected 0 schedule rows and 517 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:15:26] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:16:26] Collected 0 schedule rows and 541 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:17:26] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:18:27] Collected 0 schedule rows and 522 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:19:27] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:20:28] Collected 0 schedule rows and 523 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:21:28] Collected 0 schedule rows and 516 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:22:29] Collected 0 schedule rows and 508 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:23:29] Collected 0 schedule rows and 535 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:24:30] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:25:31] Collected 0 schedule rows and 539 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:26:31] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:27:32] Collected 0 schedule rows and 523 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:28:32] Collected 0 schedule rows and 514 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:29:33] Collected 0 schedule rows and 525 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:30:33] Collected 0 schedule rows and 538 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:31:33] Collected 0 schedule rows and 526 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:32:34] Collected 0 schedule rows and 520 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:33:34] Collected 0 schedule rows and 529 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:34:35] Collected 0 schedule rows and 520 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:35:35] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:36:36] Collected 0 schedule rows and 544 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:37:37] Collected 0 schedule rows and 533 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:38:37] Collected 0 schedule rows and 524 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:39:38] Collected 0 schedule rows and 517 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:40:39] Collected 0 schedule rows and 527 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:41:39] Collected 0 schedule rows and 521 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:42:40] Collected 0 schedule rows and 516 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:43:40] Collected 0 schedule rows and 525 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:44:41] Collected 0 schedule rows and 519 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:45:41] Collected 0 schedule rows and 531 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:46:42] Collected 0 schedule rows and 522 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:47:42] Collected 0 schedule rows and 516 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:48:43] Collected 0 schedule rows and 530 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:49:43] Collected 0 schedule rows and 523 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:50:44] Collected 0 schedule rows and 519 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:51:44] Collected 0 schedule rows and 515 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:52:45] Collected 0 schedule rows and 508 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:53:45] Collected 0 schedule rows and 524 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:54:46] Collected 0 schedule rows and 516 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:55:46] Collected 0 schedule rows and 512 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:56:47] Collected 0 schedule rows and 501 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:57:47] Collected 0 schedule rows and 491 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:58:48] Collected 0 schedule rows and 483 realtime rows.
# Waiting 1 minutes before next collection...
#
# [19:59:48] Collected 0 schedule rows and 472 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:00:49] Collected 0 schedule rows and 466 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:01:49] Collected 0 schedule rows and 480 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:02:50] Collected 0 schedule rows and 470 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:03:50] Collected 0 schedule rows and 464 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:04:51] Collected 0 schedule rows and 472 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:05:51] Collected 0 schedule rows and 466 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:06:52] Collected 0 schedule rows and 477 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:07:52] Collected 0 schedule rows and 471 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:08:53] Collected 0 schedule rows and 481 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:09:53] Collected 0 schedule rows and 475 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:10:54] Collected 0 schedule rows and 487 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:11:54] Collected 0 schedule rows and 497 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:12:55] Collected 0 schedule rows and 492 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:13:55] Collected 0 schedule rows and 505 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:14:56] Collected 0 schedule rows and 514 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:15:56] Collected 0 schedule rows and 509 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:16:57] Collected 0 schedule rows and 502 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:17:57] Collected 0 schedule rows and 494 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:18:58] Collected 0 schedule rows and 485 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:19:58] Collected 0 schedule rows and 496 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:20:59] Collected 0 schedule rows and 489 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:21:59] Collected 0 schedule rows and 504 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:22:59] Collected 0 schedule rows and 492 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:24:00] Collected 0 schedule rows and 505 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:25:00] Collected 0 schedule rows and 500 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:26:01] Collected 0 schedule rows and 511 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:27:01] Collected 0 schedule rows and 505 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:28:02] Collected 0 schedule rows and 495 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:29:02] Collected 0 schedule rows and 484 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:30:03] Collected 0 schedule rows and 475 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:31:03] Collected 0 schedule rows and 466 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:32:04] Collected 0 schedule rows and 457 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:33:04] Collected 0 schedule rows and 450 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:34:05] Collected 0 schedule rows and 480 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:35:05] Collected 0 schedule rows and 472 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:36:06] Collected 0 schedule rows and 444 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:37:06] Collected 0 schedule rows and 438 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:38:07] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:39:07] Collected 0 schedule rows and 422 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:40:08] Collected 0 schedule rows and 435 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:41:08] Collected 0 schedule rows and 447 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:42:09] Collected 0 schedule rows and 438 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:43:09] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:44:10] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:45:10] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:46:10] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:47:11] Collected 0 schedule rows and 437 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:48:11] Collected 0 schedule rows and 428 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:49:12] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:50:12] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:51:13] Collected 0 schedule rows and 431 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:52:13] Collected 0 schedule rows and 428 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:53:14] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:54:14] Collected 0 schedule rows and 434 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:55:15] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:56:15] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:57:16] Collected 0 schedule rows and 434 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:58:16] Collected 0 schedule rows and 445 realtime rows.
# Waiting 1 minutes before next collection...
#
# [20:59:17] Collected 0 schedule rows and 438 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:00:17] Collected 0 schedule rows and 472 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:01:17] Collected 0 schedule rows and 463 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:02:18] Collected 0 schedule rows and 458 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:03:18] Collected 0 schedule rows and 469 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:04:19] Collected 0 schedule rows and 461 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:05:19] Collected 0 schedule rows and 454 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:06:20] Collected 0 schedule rows and 466 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:07:20] Collected 0 schedule rows and 460 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:08:21] Collected 0 schedule rows and 450 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:09:21] Collected 0 schedule rows and 463 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:10:22] Collected 0 schedule rows and 475 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:11:22] Collected 0 schedule rows and 468 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:12:23] Collected 0 schedule rows and 459 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:13:23] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:14:24] Collected 0 schedule rows and 466 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:15:24] Collected 0 schedule rows and 458 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:16:25] Collected 0 schedule rows and 450 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:17:25] Collected 0 schedule rows and 442 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:18:26] Collected 0 schedule rows and 455 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:19:26] Collected 0 schedule rows and 470 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:20:27] Collected 0 schedule rows and 462 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:21:28] Collected 0 schedule rows and 454 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:22:28] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:23:29] Collected 0 schedule rows and 440 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:24:29] Collected 0 schedule rows and 453 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:25:29] Collected 0 schedule rows and 446 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:26:30] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:27:30] Collected 0 schedule rows and 450 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:28:31] Collected 0 schedule rows and 461 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:29:32] Collected 0 schedule rows and 457 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:30:32] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:31:33] Collected 0 schedule rows and 442 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:32:33] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:33:33] Collected 0 schedule rows and 431 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:34:34] Collected 0 schedule rows and 421 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:35:34] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:36:35] Collected 0 schedule rows and 465 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:37:35] Collected 0 schedule rows and 459 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:38:36] Collected 0 schedule rows and 454 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:39:36] Collected 0 schedule rows and 445 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:40:37] Collected 0 schedule rows and 440 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:41:37] Collected 0 schedule rows and 451 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:42:37] Collected 0 schedule rows and 445 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:43:38] Collected 0 schedule rows and 458 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:44:38] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:45:39] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:46:40] Collected 0 schedule rows and 456 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:47:40] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:48:40] Collected 0 schedule rows and 461 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:49:41] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:50:41] Collected 0 schedule rows and 446 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:51:42] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:52:42] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:53:43] Collected 0 schedule rows and 446 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:54:43] Collected 0 schedule rows and 455 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:55:44] Collected 0 schedule rows and 451 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:56:45] Collected 0 schedule rows and 442 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:57:45] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:58:46] Collected 0 schedule rows and 446 realtime rows.
# Waiting 1 minutes before next collection...
#
# [21:59:46] Collected 0 schedule rows and 441 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:00:46] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:01:47] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:02:47] Collected 0 schedule rows and 437 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:03:48] Collected 0 schedule rows and 431 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:04:48] Collected 0 schedule rows and 444 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:05:49] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:06:50] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:07:50] Collected 0 schedule rows and 427 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:08:51] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:09:51] Collected 0 schedule rows and 432 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:10:51] Collected 0 schedule rows and 424 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:11:52] Collected 0 schedule rows and 415 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:12:52] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:13:53] Collected 0 schedule rows and 442 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:14:53] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:15:54] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:16:54] Collected 0 schedule rows and 440 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:17:55] Collected 0 schedule rows and 454 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:18:55] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:19:56] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:20:56] Collected 0 schedule rows and 435 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:21:57] Collected 0 schedule rows and 428 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:22:57] Collected 0 schedule rows and 461 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:23:58] Collected 0 schedule rows and 453 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:24:58] Collected 0 schedule rows and 448 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:25:59] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:26:59] Collected 0 schedule rows and 436 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:28:00] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:29:00] Collected 0 schedule rows and 423 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:30:01] Collected 0 schedule rows and 452 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:31:01] Collected 0 schedule rows and 450 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:32:02] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:33:02] Collected 0 schedule rows and 437 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:34:02] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:35:03] Collected 0 schedule rows and 444 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:36:03] Collected 0 schedule rows and 433 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:37:04] Collected 0 schedule rows and 431 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:38:04] Collected 0 schedule rows and 423 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:39:05] Collected 0 schedule rows and 418 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:40:05] Collected 0 schedule rows and 413 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:41:06] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:42:06] Collected 0 schedule rows and 417 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:43:07] Collected 0 schedule rows and 432 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:44:07] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:45:08] Collected 0 schedule rows and 421 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:46:08] Collected 0 schedule rows and 414 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:47:09] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:48:09] Collected 0 schedule rows and 417 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:49:10] Collected 0 schedule rows and 409 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:50:10] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:51:11] Collected 0 schedule rows and 435 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:52:11] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:53:12] Collected 0 schedule rows and 426 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:54:12] Collected 0 schedule rows and 421 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:55:13] Collected 0 schedule rows and 413 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:56:13] Collected 0 schedule rows and 432 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:57:14] Collected 0 schedule rows and 426 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:58:14] Collected 0 schedule rows and 420 realtime rows.
# Waiting 1 minutes before next collection...
#
# [22:59:15] Collected 0 schedule rows and 430 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:00:15] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:01:16] Collected 0 schedule rows and 441 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:02:17] Collected 0 schedule rows and 431 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:03:17] Collected 0 schedule rows and 443 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:04:18] Collected 0 schedule rows and 439 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:05:18] Collected 0 schedule rows and 435 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:06:19] Collected 0 schedule rows and 428 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:07:19] Collected 0 schedule rows and 425 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:08:20] Collected 0 schedule rows and 414 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:09:20] Collected 0 schedule rows and 429 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:10:21] Collected 0 schedule rows and 419 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:11:21] Collected 0 schedule rows and 415 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:12:22] Collected 0 schedule rows and 412 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:13:22] Collected 0 schedule rows and 405 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:14:22] Collected 0 schedule rows and 400 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:15:23] Collected 0 schedule rows and 411 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:16:24] Collected 0 schedule rows and 422 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:17:25] Collected 0 schedule rows and 417 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:18:25] Collected 0 schedule rows and 412 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:19:26] Collected 0 schedule rows and 405 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:20:26] Collected 0 schedule rows and 401 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:21:27] Collected 0 schedule rows and 411 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:22:27] Collected 0 schedule rows and 405 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:23:28] Collected 0 schedule rows and 397 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:24:28] Collected 0 schedule rows and 392 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:25:29] Collected 0 schedule rows and 404 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:26:29] Collected 0 schedule rows and 399 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:27:30] Collected 0 schedule rows and 392 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:28:31] Collected 0 schedule rows and 386 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:29:31] Collected 0 schedule rows and 417 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:30:31] Collected 0 schedule rows and 410 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:31:32] Collected 0 schedule rows and 423 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:32:32] Collected 0 schedule rows and 418 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:33:33] Collected 0 schedule rows and 412 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:34:33] Collected 0 schedule rows and 408 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:35:34] Collected 0 schedule rows and 415 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:36:34] Collected 0 schedule rows and 411 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:37:35] Collected 0 schedule rows and 403 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:38:35] Collected 0 schedule rows and 399 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:39:36] Collected 0 schedule rows and 409 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:40:36] Collected 0 schedule rows and 421 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:41:37] Collected 0 schedule rows and 417 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:42:37] Collected 0 schedule rows and 411 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:43:38] Collected 0 schedule rows and 406 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:44:38] Collected 0 schedule rows and 399 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:45:39] Collected 0 schedule rows and 394 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:46:39] Collected 0 schedule rows and 387 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:47:40] Collected 0 schedule rows and 383 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:48:40] Collected 0 schedule rows and 373 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:49:40] Collected 0 schedule rows and 367 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:50:41] Collected 0 schedule rows and 359 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:51:41] Collected 0 schedule rows and 353 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:52:42] Collected 0 schedule rows and 350 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:53:42] Collected 0 schedule rows and 343 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:54:44] Collected 0 schedule rows and 333 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:55:44] Collected 0 schedule rows and 328 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:56:45] Collected 0 schedule rows and 323 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:57:45] Collected 0 schedule rows and 319 realtime rows.
# Waiting 1 minutes before next collection...
#
# [23:58:46] Collected 0 schedule rows and 313 realtime rows.
# Data Collection Complete.

# %% [markdown]
# ## Cleaning the data

# %%
df_schedule = pd.read_csv("orange_line_schedule_live.csv", low_memory=False)
df_realtime = pd.read_csv("orange_line_realtime_live.csv", low_memory=False)

print(df_schedule.dtypes)
print(df_realtime.dtypes)

# converting types
#     --- standardizing the IDs ----
id_columns = ['trip_id', 'stop_id']  # adjust if needed
for col in id_columns:
    df_schedule[col] = df_schedule[col].astype(str).str.strip().str.upper()
    df_realtime[col] = df_realtime[col].astype(str).str.strip().str.upper()

#     --- converting to eastern time ----
time_columns = ['departure_time', 'arrival_time']
for col in time_columns:
    df_schedule[col] = pd.to_datetime(df_schedule[col], errors='coerce', utc=True)
    df_schedule[col] = df_schedule[col].dt.tz_convert('America/New_York')
    
    df_realtime[col] = pd.to_datetime(df_realtime[col], errors='coerce', utc=True)
    df_realtime[col] = df_realtime[col].dt.tz_convert('America/New_York')

# dropping nulls
df_schedule_clean = df_schedule.dropna(subset=['trip_id', 'stop_id']).reset_index(drop=True)
df_realtime_clean = df_realtime.dropna(subset=['trip_id', 'stop_id']).reset_index(drop=True)

df_schedule_clean = df_schedule_clean.drop_duplicates(subset=['trip_id', 'stop_id', 'departure_time']).reset_index(drop=True)
df_realtime_clean = (
    df_realtime_clean.sort_values('departure_time')
    .drop_duplicates(subset=['trip_id', 'stop_id'], keep='last')
    .reset_index(drop=True)
)


print(df_schedule_clean.dtypes)
print(df_realtime_clean.dtypes)
# Out:
# trip_id                 int64
# stop_id                 int64
# stop_sequence           int64
# arrival_time           object
# departure_time         object
# direction_id            int64
# timestamp_collected    object
# schedule_type          object
# dtype: object
# trip_id                object
# stop_id                object
# arrival_time           object
# departure_time         object
# status                 object
# direction_id            int64
# timestamp_collected    object
# schedule_type          object
# dtype: object
# trip_id                                          object
# stop_id                                          object
# stop_sequence                                     int64
# arrival_time           datetime64[ns, America/New_York]
# departure_time         datetime64[ns, America/New_York]
# direction_id                                      int64
# timestamp_collected                              object
# schedule_type                                    object
# dtype: object
# trip_id                                          object
# stop_id                                          object
# arrival_time           datetime64[ns, America/New_York]
# departure_time         datetime64[ns, America/New_York]
# status                                           object
# direction_id                                      int64
# timestamp_collected                              object
# schedule_type                                    object
# dtype: object

# %% [markdown]
# ## Merging the Data

# %%
df_merge_debug = pd.merge(
    df_schedule_clean,
    df_realtime_clean,
    on=['trip_id', 'stop_id'],
    how='outer',
    indicator=True
)

print("Merge counts:")
print(df_merge_debug['_merge'].value_counts())
# '_merge' values: 'left_only', 'right_only', 'both'
# Out:
# Merge counts:
# _merge
# both          4107
# right_only     652
# left_only        4
# Name: count, dtype: int64

# %%
df_merged = pd.merge(
    df_schedule_clean,
    df_realtime_clean,
    on=['trip_id', 'stop_id'],
    how='inner',  # only rows present in both
    suffixes=('_schedule', '_realtime')
)

df_merged_filtered = df_merged.dropna(subset=['departure_time_schedule', 'departure_time_realtime']).reset_index(drop=True)


df_merged_filtered['delay_minutes'] = (
    df_merged_filtered['departure_time_realtime'] - df_merged_filtered['departure_time_schedule']
).dt.total_seconds() / 60

print(df_merged_filtered.head(20))
print(df_merged_filtered.shape)

df_merged_filtered.to_csv("orange_line_merged.csv", index=False)
# Out:
#      trip_id stop_id  stop_sequence     arrival_time_schedule  \
# 0   70525422   70033            170 2025-11-05 14:56:00-05:00
# 1   70525422   70035            180 2025-11-05 15:00:00-05:00
# 2   70525430   70029            140 2025-11-05 14:56:00-05:00
# 3   70525430   70031            150 2025-11-05 14:58:00-05:00
# 4   70525430   70279            160 2025-11-05 15:00:00-05:00
# 5   70525430   70033            170 2025-11-05 15:02:00-05:00
# 6   70525430   70035            180 2025-11-05 15:06:00-05:00
# 7   70525438   70021            100 2025-11-05 14:55:00-05:00
# 8   70525438   70023            110 2025-11-05 14:57:00-05:00
# 9   70525438   70025            120 2025-11-05 14:58:00-05:00
# 10  70525438   70027            130 2025-11-05 15:00:00-05:00
# 11  70525438   70029            140 2025-11-05 15:02:00-05:00
# 12  70525438   70031            150 2025-11-05 15:04:00-05:00
# 13  70525438   70279            160 2025-11-05 15:06:00-05:00
# 14  70525438   70033            170 2025-11-05 15:08:00-05:00
# 15  70525438   70035            180 2025-11-05 15:12:00-05:00
# 16  70525469   70036              1                       NaT
# 17  70525469   70034             10 2025-11-05 15:22:00-05:00
# 18  70525469   70032             20 2025-11-05 15:26:00-05:00
# 19  70525469   70278             30 2025-11-05 15:28:00-05:00
#
#      departure_time_schedule  direction_id_schedule  \
# 0  2025-11-05 14:56:00-05:00                      1
# 1  2025-11-05 15:00:00-05:00                      1
# 2  2025-11-05 14:56:00-05:00                      1
# 3  2025-11-05 14:58:00-05:00                      1
# 4  2025-11-05 15:00:00-05:00                      1
# 5  2025-11-05 15:02:00-05:00                      1
# 6  2025-11-05 15:06:00-05:00                      1
# 7  2025-11-05 14:55:00-05:00                      1
# 8  2025-11-05 14:57:00-05:00                      1
# 9  2025-11-05 14:58:00-05:00                      1
# 10 2025-11-05 15:00:00-05:00                      1
# 11 2025-11-05 15:02:00-05:00                      1
# 12 2025-11-05 15:04:00-05:00                      1
# 13 2025-11-05 15:06:00-05:00                      1
# 14 2025-11-05 15:08:00-05:00                      1
# 15 2025-11-05 15:12:00-05:00                      1
# 16 2025-11-05 15:21:00-05:00                      0
# 17 2025-11-05 15:22:00-05:00                      0
# 18 2025-11-05 15:26:00-05:00                      0
# 19 2025-11-05 15:28:00-05:00                      0
#
#         timestamp_collected_schedule schedule_type_schedule  \
# 0   2025-11-05T14:55:04.295171-05:00                planned
# 1   2025-11-05T14:55:04.295171-05:00                planned
# 2   2025-11-05T14:55:04.295171-05:00                planned
# 3   2025-11-05T14:55:04.295171-05:00                planned
# 4   2025-11-05T14:55:04.295171-05:00                planned
# 5   2025-11-05T14:55:04.295171-05:00                planned
# 6   2025-11-05T14:55:04.295171-05:00                planned
# 7   2025-11-05T14:55:04.295171-05:00                planned
# 8   2025-11-05T14:55:04.295171-05:00                planned
# 9   2025-11-05T14:55:04.295171-05:00                planned
# 10  2025-11-05T14:55:04.295171-05:00                planned
# 11  2025-11-05T14:55:04.295171-05:00                planned
# 12  2025-11-05T14:55:04.295171-05:00                planned
# 13  2025-11-05T14:55:04.295171-05:00                planned
# 14  2025-11-05T14:55:04.295171-05:00                planned
# 15  2025-11-05T14:55:04.295171-05:00                planned
# 16  2025-11-05T14:55:04.295171-05:00                planned
# 17  2025-11-05T14:55:04.295171-05:00                planned
# 18  2025-11-05T14:55:04.295171-05:00                planned
# 19  2025-11-05T14:55:04.295171-05:00                planned
#
#        arrival_time_realtime   departure_time_realtime status  \
# 0  2025-11-05 14:52:57-05:00 2025-11-05 14:54:16-05:00    NaN
# 1  2025-11-05 14:56:28-05:00 2025-11-05 14:57:27-05:00    NaN
# 2  2025-11-05 14:52:31-05:00 2025-11-05 14:53:27-05:00    NaN
# 3  2025-11-05 14:54:40-05:00 2025-11-05 14:55:43-05:00    NaN
# 4  2025-11-05 14:56:29-05:00 2025-11-05 14:57:23-05:00    NaN
# 5  2025-11-05 14:58:14-05:00 2025-11-05 14:59:25-05:00    NaN
# 6  2025-11-05 15:01:34-05:00 2025-11-05 15:02:24-05:00    NaN
# 7  2025-11-05 14:49:46-05:00 2025-11-05 14:50:51-05:00    NaN
# 8  2025-11-05 14:51:13-05:00 2025-11-05 14:52:02-05:00    NaN
# 9  2025-11-05 14:52:26-05:00 2025-11-05 14:53:10-05:00    NaN
# 10 2025-11-05 14:53:41-05:00 2025-11-05 14:54:27-05:00    NaN
# 11 2025-11-05 14:55:54-05:00 2025-11-05 14:56:56-05:00    NaN
# 12 2025-11-05 14:58:09-05:00 2025-11-05 14:59:31-05:00    NaN
# 13 2025-11-05 15:00:19-05:00 2025-11-05 15:01:13-05:00    NaN
# 14 2025-11-05 15:02:05-05:00 2025-11-05 15:03:10-05:00    NaN
# 15 2025-11-05 15:05:20-05:00 2025-11-05 15:06:10-05:00    NaN
# 16                       NaT 2025-11-05 15:21:30-05:00    NaN
# 17 2025-11-05 15:22:56-05:00 2025-11-05 15:23:45-05:00    NaN
# 18 2025-11-05 15:26:03-05:00 2025-11-05 15:26:57-05:00    NaN
# 19 2025-11-05 15:27:46-05:00 2025-11-05 15:28:32-05:00    NaN
#
#     direction_id_realtime      timestamp_collected_realtime  \
# 0                       1  2025-11-05T14:56:05.795084-05:00
# 1                       1  2025-11-05T14:58:07.838004-05:00
# 2                       1  2025-11-05T14:56:05.795084-05:00
# 3                       1  2025-11-05T14:55:04.295171-05:00
# 4                       1  2025-11-05T14:55:04.295171-05:00
# 5                       1  2025-11-05T14:55:04.295171-05:00
# 6                       1  2025-11-05T14:59:09.120731-05:00
# 7                       1  2025-11-05T14:55:04.295171-05:00
# 8                       1  2025-11-05T14:55:04.295171-05:00
# 9                       1  2025-11-05T14:56:05.795084-05:00
# 10                      1  2025-11-05T14:59:09.120731-05:00
# 11                      1  2025-11-05T15:00:10.310908-05:00
# 12                      1  2025-11-05T15:00:10.310908-05:00
# 13                      1  2025-11-05T15:01:11.425061-05:00
# 14                      1  2025-11-05T15:01:11.425061-05:00
# 15                      1  2025-11-05T15:01:11.425061-05:00
# 16                      0  2025-11-05T15:07:14.412536-05:00
# 17                      0  2025-11-05T14:56:05.795084-05:00
# 18                      0  2025-11-05T15:26:25.087507-05:00
# 19                      0  2025-11-05T15:26:25.087507-05:00
#
#    schedule_type_realtime  delay_minutes
# 0                realtime      -1.733333
# 1                realtime      -2.550000
# 2                realtime      -2.550000
# 3                realtime      -2.283333
# 4                realtime      -2.616667
# 5                realtime      -2.583333
# 6                realtime      -3.600000
# 7                realtime      -4.150000
# 8                realtime      -4.966667
# 9                realtime      -4.833333
# 10               realtime      -5.550000
# 11               realtime      -5.066667
# 12               realtime      -4.483333
# 13               realtime      -4.783333
# 14               realtime      -4.833333
# 15               realtime      -5.833333
# 16               realtime       0.500000
# 17               realtime       1.750000
# 18               realtime       0.950000
# 19               realtime       0.533333
# (3901, 15)
